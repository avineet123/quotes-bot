# %%
! pip install chatterbot

# %%
import pandas as pd
import numpy as np
from chatterbot import Chatbot
from chatterbot.train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-2dc7c67cd347> in <module>
#       4 import random
#       5 import string # to process standard python strings
# ----> 6 from chatterbot import Chatbot
#
# ModuleNotFoundError: No module named 'chatterbot'

# %%
dataset=pd.read_csv('out_data1.csv',encoding ='latin1')
dataset
# Out:
#                                                  hrefs  \
# 0              /quotes/carol_burnett_371189?src=t_life
# 1         /quotes/charles_r_swindoll_388332?src=t_life
# 2                /quotes/george_sand_383232?src=t_life
# 3          /quotes/hubert_h_humphrey_152599?src=t_life
# 4         /quotes/simone_de_beauvoir_149611?src=t_life
# 5                   /quotes/yoko_ono_460619?src=t_life
# 6            /quotes/kenneth_branagh_714629?src=t_life
# 7            /quotes/thich_nhat_hanh_531566?src=t_life
# 8             /quotes/norman_cousins_121747?src=t_life
# 9               /quotes/matt_cameron_333397?src=t_life
# 10         /quotes/michael_imperioli_431582?src=t_life
# 11              /quotes/philip_green_173402?src=t_life
# 12            /quotes/john_w_gardner_161655?src=t_life
# 13       /quotes/kareena_kapoor_khan_513474?src=t_life
# 14              /quotes/omar_khayyam_378553?src=t_life
# 15           /quotes/william_barclay_186927?src=t_life
# ...

# %%
new = dataset["hrefs"].str.split("src=t_", n = 1, expand = True)
# Out:
#                                            0     1
# 0              /quotes/carol_burnett_371189?  life
# 1         /quotes/charles_r_swindoll_388332?  life
# 2                /quotes/george_sand_383232?  life
# 3          /quotes/hubert_h_humphrey_152599?  life
# 4         /quotes/simone_de_beauvoir_149611?  life
# 5                   /quotes/yoko_ono_460619?  life
# 6            /quotes/kenneth_branagh_714629?  life
# 7            /quotes/thich_nhat_hanh_531566?  life
# 8             /quotes/norman_cousins_121747?  life
# 9               /quotes/matt_cameron_333397?  life
# 10         /quotes/michael_imperioli_431582?  life
# 11              /quotes/philip_green_173402?  life
# 12            /quotes/john_w_gardner_161655?  life
# 13       /quotes/kareena_kapoor_khan_513474?  life
# 14              /quotes/omar_khayyam_378553?  life
# 15           /quotes/william_barclay_186927?  life
# 16             /quotes/henry_rollins_381421?  life
# ...

# %%
dataset['quotes_type']=new[1]
dataset
# Out:
#                                                  hrefs  \
# 0              /quotes/carol_burnett_371189?src=t_life
# 1         /quotes/charles_r_swindoll_388332?src=t_life
# 2                /quotes/george_sand_383232?src=t_life
# 3          /quotes/hubert_h_humphrey_152599?src=t_life
# 4         /quotes/simone_de_beauvoir_149611?src=t_life
# 5                   /quotes/yoko_ono_460619?src=t_life
# 6            /quotes/kenneth_branagh_714629?src=t_life
# 7            /quotes/thich_nhat_hanh_531566?src=t_life
# 8             /quotes/norman_cousins_121747?src=t_life
# 9               /quotes/matt_cameron_333397?src=t_life
# 10         /quotes/michael_imperioli_431582?src=t_life
# 11              /quotes/philip_green_173402?src=t_life
# 12            /quotes/john_w_gardner_161655?src=t_life
# 13       /quotes/kareena_kapoor_khan_513474?src=t_life
# 14              /quotes/omar_khayyam_378553?src=t_life
# 15           /quotes/william_barclay_186927?src=t_life
# ...

# %%
author = dataset["lines"].str.split(".-", n = 1, expand = True)

# %%
dataset["quotes_lines"]=author[0]
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f2037bbf66fb> in <module>
# ----> 1 dataset["quotes_lines"]=author[0]
#       2 dataset
#
# NameError: name 'author' is not defined

# %%
dataset=dataset.drop(['lines', 'hrefs'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be258a902fbd> in <module>
# ----> 1 dataset=dataset.drop(['lines', 'hrefs'], axis=1)
#
# NameError: name 'dataset' is not defined

# %%
dataset
# Out:
#                                                  hrefs  \
# 0              /quotes/carol_burnett_371189?src=t_life
# 1         /quotes/charles_r_swindoll_388332?src=t_life
# 2                /quotes/george_sand_383232?src=t_life
# 3          /quotes/hubert_h_humphrey_152599?src=t_life
# 4         /quotes/simone_de_beauvoir_149611?src=t_life
# 5                   /quotes/yoko_ono_460619?src=t_life
# 6            /quotes/kenneth_branagh_714629?src=t_life
# 7            /quotes/thich_nhat_hanh_531566?src=t_life
# 8             /quotes/norman_cousins_121747?src=t_life
# 9               /quotes/matt_cameron_333397?src=t_life
# 10         /quotes/michael_imperioli_431582?src=t_life
# 11              /quotes/philip_green_173402?src=t_life
# 12            /quotes/john_w_gardner_161655?src=t_life
# 13       /quotes/kareena_kapoor_khan_513474?src=t_life
# 14              /quotes/omar_khayyam_378553?src=t_life
# 15           /quotes/william_barclay_186927?src=t_life
# ...

# %%
dataset
# Out:
# C:\Users\My Pc\Miniconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3075b36c09c8> in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined
